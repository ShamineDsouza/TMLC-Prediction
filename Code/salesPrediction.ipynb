# %%
import os
import pandas as pd
import numpy as np
from os.path import dirname, abspath

# %%
dfTrain = pd.read_csv("FileFolder\\train_v9rqX0R.csv")
dfTest = pd.read_csv("FileFolder\\test_AbJTz2l.csv")
print("Top 5 rows: \n")
dfTrain.head(5) # top 5 rows

# Columns #
# Categorical Column 
# Item_type
# Outlet_Size
# Outlet_Location_type
# Outlet_type
# Item_Fat_Content

# Numerical Vaibles
# Item_Weight
# Item_Visibility
# Item_MRP

# Target
# Item_Outlet_Sales
# Out:
# Top 5 rows:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat         0.016047
# 1           DRC01         5.92          Regular         0.019278
# 2           FDN15        17.50          Low Fat         0.016760
# 3           FDX07        19.20          Regular         0.000000
# 4           NCD19         8.93          Low Fat         0.000000
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy  249.8092            OUT049
# 1            Soft Drinks   48.2692            OUT018
# 2                   Meat  141.6180            OUT049
# 3  Fruits and Vegetables  182.0950            OUT010
# 4              Household   53.8614            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
print("Info: \n")
print(dfTrain.info())
# Out:
# Info:
#
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8523 entries, 0 to 8522
# Data columns (total 12 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Item_Identifier            8523 non-null   object
#  1   Item_Weight                7060 non-null   float64
#  2   Item_Fat_Content           8523 non-null   object
#  3   Item_Visibility            8523 non-null   float64
#  4   Item_Type                  8523 non-null   object
#  5   Item_MRP                   8523 non-null   float64
#  6   Outlet_Identifier          8523 non-null   object
#  7   Outlet_Establishment_Year  8523 non-null   int64
#  8   Outlet_Size                6113 non-null   object
#  9   Outlet_Location_Type       8523 non-null   object
#  10  Outlet_Type                8523 non-null   object
#  11  Item_Outlet_Sales          8523 non-null   float64
# dtypes: float64(4), int64(1), object(7)
# memory usage: 799.2+ KB
# None

# %%
print("Describe: \n")
print(dfTrain.describe())
# Out:
# Describe:
#
#        Item_Weight  Item_Visibility     Item_MRP  Outlet_Establishment_Year  \
# count  7060.000000      8523.000000  8523.000000                8523.000000
# mean     12.857645         0.066132   140.992782                1997.831867
# std       4.643456         0.051598    62.275067                   8.371760
# min       4.555000         0.000000    31.290000                1985.000000
# 25%       8.773750         0.026989    93.826500                1987.000000
# 50%      12.600000         0.053931   143.012800                1999.000000
# 75%      16.850000         0.094585   185.643700                2004.000000
# max      21.350000         0.328391   266.888400                2009.000000
#
#        Item_Outlet_Sales
# count        8523.000000
# mean         2181.288914
# std          1706.499616
# min            33.290000
# 25%           834.247400
# 50%          1794.331000
# 75%          3101.296400
# max         13086.964800

# %%
dfTrain.isnull().sum() # Naull values are present iN Outlet_Size, Item_Weight
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
print("Outlet_Type:-")
print(dfTrain['Outlet_Type'].unique())
print("Outlet_Identifier:-")
print(dfTrain['Outlet_Identifier'].unique())
print("Item_Type:-")
print(dfTrain['Item_Type'].unique())
print("Outlet_Location_Type:-")
print(dfTrain['Outlet_Location_Type'].unique())
print("Outlet_Size:-")
print(dfTrain['Outlet_Size'].unique())
# Out:
# Outlet_Type:-
# ['Supermarket Type1' 'Supermarket Type2' 'Grocery Store'
#  'Supermarket Type3']
# Outlet_Identifier:-
# ['OUT049' 'OUT018' 'OUT010' 'OUT013' 'OUT027' 'OUT045' 'OUT017' 'OUT046'
#  'OUT035' 'OUT019']
# Item_Type:-
# ['Dairy' 'Soft Drinks' 'Meat' 'Fruits and Vegetables' 'Household'
#  'Baking Goods' 'Snack Foods' 'Frozen Foods' 'Breakfast'
#  'Health and Hygiene' 'Hard Drinks' 'Canned' 'Breads' 'Starchy Foods'
#  'Others' 'Seafood']
# Outlet_Location_Type:-
# ['Tier 1' 'Tier 3' 'Tier 2']
# Outlet_Size:-
# ['Medium' nan 'High' 'Small']

# %%
dfTrain.shape
# Out:
# (8523, 12)

# %%
dfTrain.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                  1463
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dfTrain['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
print("Item_Identifier:-")
print(dfTrain['Item_Identifier'].unique())
print(dfTrain['Item_Identifier'].nunique())
# Out:
# Item_Identifier:-
# ['FDA15' 'DRC01' 'FDN15' ... 'NCF55' 'NCW30' 'NCW05']
# 1559

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# Bivariate analysis

# %%
# dfTrainTest1 = dfTrain[['Outlet_Location_Type', 'Outlet_Type', 'Outlet_Identifier']].value_counts(ascending=True).reset_index(name='count')
# dfTrainTest1.head(20)

# for each Tier -> differnt market type = the total  sales 

pd.options.display.float_format = '{:.2f}'.format
dfTrainTest2 = dfTrain.groupby(['Outlet_Location_Type', 'Outlet_Type', 'Outlet_Identifier'])['Item_Outlet_Sales'].sum().reset_index(name='total')
dfTrainTest2.head(20)
# Out:
#   Outlet_Location_Type        Outlet_Type Outlet_Identifier      total
# 0               Tier 1      Grocery Store            OUT019  179694.09
# 1               Tier 1  Supermarket Type1            OUT046 2118395.17
# 2               Tier 1  Supermarket Type1            OUT049 2183969.81
# 3               Tier 2  Supermarket Type1            OUT017 2167465.29
# 4               Tier 2  Supermarket Type1            OUT035 2268122.94
# 5               Tier 2  Supermarket Type1            OUT045 2036725.48
# 6               Tier 3      Grocery Store            OUT010  188340.17
# 7               Tier 3  Supermarket Type1            OUT013 2142663.58
# 8               Tier 3  Supermarket Type2            OUT018 1851822.83
# 9               Tier 3  Supermarket Type3            OUT027 3453926.05

# %%
plt.figure(figsize=(20,6))

sns.set_theme(style="whitegrid")
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=dfTrainTest2, kind="bar", x="Outlet_Location_Type", y="total", hue="Outlet_Type", palette="dark", alpha=.6, height=10)
g.despine(left=True)
g.set_axis_labels("Outlet location Type", "Sales")
g.legend.set_title("Geographical Sales ")


# Tier 3 outlets perform more
# Tier2 on Sopermarket Type 1 
# Tier 1 , little grocery store , but more super market 1

# %%
pd.options.display.float_format = '{:.2f}'.format
dfTrainTest3 = dfTrain.groupby(['Outlet_Location_Type', 'Outlet_Type', 'Outlet_Identifier', 'Item_Type'])['Item_Outlet_Sales'].sum().reset_index(name='total')
dfTrainTest3.head(1000)
# Out:
#     Outlet_Location_Type        Outlet_Type Outlet_Identifier      Item_Type  \
# 0                 Tier 1      Grocery Store            OUT019   Baking Goods
# 1                 Tier 1      Grocery Store            OUT019         Breads
# 2                 Tier 1      Grocery Store            OUT019      Breakfast
# 3                 Tier 1      Grocery Store            OUT019         Canned
# 4                 Tier 1      Grocery Store            OUT019          Dairy
# ..                   ...                ...               ...            ...
# 155               Tier 3  Supermarket Type3            OUT027         Others
# 156               Tier 3  Supermarket Type3            OUT027        Seafood
# 157               Tier 3  Supermarket Type3            OUT027    Snack Foods
# 158               Tier 3  Supermarket Type3            OUT027    Soft Drinks
# 159               Tier 3  Supermarket Type3            OUT027  Starchy Foods
#
#         total
# 0    14133.60
# ...

# %%
#Checking the Item sales for each outlet Identifier
title = 'Outlet Vs Item_Type Sales'
plt.figure(figsize=(20,10))

sns.relplot(dfTrainTest3.Outlet_Identifier, dfTrainTest3.total,hue=dfTrainTest3.Item_Type, kind="line", height=9,)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
pd.options.display.float_format = '{:.2f}'.format
dfTrainTest4 = dfTrain.groupby(['Outlet_Location_Type', 'Outlet_Identifier','Outlet_Establishment_Year'])['Item_Outlet_Sales'].sum().reset_index(name='total')

dfTrainTest4['Outlet'] = dfTrainTest4["Outlet_Identifier"] + "-"  + dfTrainTest4["Outlet_Establishment_Year"].astype(str)

# for index, row in dfTrainTest4.iterrows():
#     print(row[1])
#     row["Outlet"] = row["Outlet_Identifier"] + "-"  + str(row["Outlet_Establishment_Year"])

# dfTrainTest4["Outlet"] = dfTrainTest4["Outlet_Identifier"] + "-"  + str(dfTrainTest4["Outlet_Establishment_Year"])
dfTrainTest4.head(1000)
# Out:
#   Outlet_Location_Type Outlet_Identifier  Outlet_Establishment_Year  \
# 0               Tier 1            OUT019                       1985
# 1               Tier 1            OUT046                       1997
# 2               Tier 1            OUT049                       1999
# 3               Tier 2            OUT017                       2007
# 4               Tier 2            OUT035                       2004
# 5               Tier 2            OUT045                       2002
# 6               Tier 3            OUT010                       1998
# 7               Tier 3            OUT013                       1987
# 8               Tier 3            OUT018                       2009
# 9               Tier 3            OUT027                       1985
#
#        total       Outlet
# 0  179694.09  OUT019-1985
# 1 2118395.17  OUT046-1997
# 2 2183969.81  OUT049-1999
# 3 2167465.29  OUT017-2007
# 4 2268122.94  OUT035-2004
# 5 2036725.48  OUT045-2002
# 6  188340.17  OUT010-1998
# ...

# %%
plt.figure(figsize=(20,6))

sns.set_theme(style="whitegrid")
# Draw a nested barplot by species and sex
g = sns.catplot(
    data=dfTrainTest4, kind="bar",
    x="Outlet_Location_Type", y="total", hue="Outlet",
     palette="dark", alpha=.6, height=10
)
g.despine(left=True)
g.set_axis_labels("Outlet location Type", " Total Sales")
g.legend.set_title("Geographical Sales ")

# %%
dowjones = dfTrainTest4
sns.relplot(data=dowjones, x="Outlet_Establishment_Year", y="total", kind="line")

# %%
# Univariate analysis

# %%
#plotting distribution of dataset based on neighbourhood_group
plt.figure(figsize = (10,5))
sns.countplot(x="Outlet_Identifier", data=dfTrain)
plt.show()

# Total Count of enteries per Outlet entity

# %%
#Checking the Item sales for each outlet Identifier
title = 'Outlet_Identifier Vs Item_Type Sales'
plt.figure(figsize=(10,6))
sns.scatterplot(dfTrain.Outlet_Identifier, dfTrain.Item_Type,hue=dfTrain.Item_Outlet_Sales).set_title(title)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# Box plot

# %%
plt.figure(figsize = (10,5))
sns.set_theme(style="whitegrid")
ax = sns.boxplot(x="Item_Outlet_Sales", y="Outlet_Identifier", data=dfTrain)
plt.show()

# %%
dfTrainTest4.head(10)
# Out:
#   Outlet_Location_Type Outlet_Identifier  Outlet_Establishment_Year  \
# 0               Tier 1            OUT019                       1985
# 1               Tier 1            OUT046                       1997
# 2               Tier 1            OUT049                       1999
# 3               Tier 2            OUT017                       2007
# 4               Tier 2            OUT035                       2004
# 5               Tier 2            OUT045                       2002
# 6               Tier 3            OUT010                       1998
# 7               Tier 3            OUT013                       1987
# 8               Tier 3            OUT018                       2009
# 9               Tier 3            OUT027                       1985
#
#        total       Outlet
# 0  179694.09  OUT019-1985
# 1 2118395.17  OUT046-1997
# 2 2183969.81  OUT049-1999
# 3 2167465.29  OUT017-2007
# 4 2268122.94  OUT035-2004
# 5 2036725.48  OUT045-2002
# 6  188340.17  OUT010-1998
# ...

# %%
#Checking the Item sales for each outlet Identifier
title = 'Outlet_Identifier Vs Item_Type Sales'
plt.figure(figsize=(10,6))
sns.scatterplot(dfTrainTest2.Outlet_Location_Type, dfTrainTest2.total,hue=dfTrainTest2.Outlet_Location_Type).set_title(title)
plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
# sales per Tier
sns.barplot(x="Outlet_Location_Type", y="total", data=dfTrainTest2)
# Show the plot
plt.show()

# %%
# sales per Identifier
plt.figure(figsize=(10,6))
sns.barplot(x="Outlet_Identifier", y="total", data=dfTrainTest2)
# Show the plot
plt.show()

# %%
# sales per Type
plt.figure(figsize=(10,6))
sns.barplot(x="Outlet_Type", y="total", data=dfTrainTest2)
# Show the plot
plt.show()

# %%
plt.figure(figsize=(10,6))
# Draw a categorical scatterplot to show each observation
ax = sns.swarmplot(data=dfTrainTest2, x="Outlet_Location_Type", y="total", hue="Outlet_Type")
ax.set(ylabel="")
# Out:
# [Text(0, 0.5, '')]

# %% [markdown]
# ### Data Cleaning ####

# %%
dfTrain.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
# 5           FDP36        10.39          Regular             0.00
# 6           FDO10        13.65          Regular             0.01
# 7           FDP10          NaN          Low Fat             0.13
# 8           FDH17        16.20          Regular             0.02
# 9           FDU28        19.20          Regular             0.09
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# ...

# %%
plt.figure(figsize = (30,10))
plt.boxplot(dfTrain['Item_Outlet_Sales'], vert = False)
plt.ylabel('Sales')
plt.xlabel('Number')
plt.show()

# %%
dfTrain[dfTrain['Item_Outlet_Sales'] > 12000].head()
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 5223           FDQ19          NaN          Regular             0.01
# 7188           NCE42          NaN          Low Fat             0.01
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 5223  Fruits and Vegetables    242.65            OUT027
# 7188              Household    235.00            OUT027
#
#       Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 5223                       1985      Medium               Tier 3
# 7188                       1985      Medium               Tier 3
#
#             Outlet_Type  Item_Outlet_Sales
# 5223  Supermarket Type3           12117.56
# 7188  Supermarket Type3           13086.96

# %%
dfTrain.isnull().sum()
# Out:
# Item_Identifier                 0
# Item_Weight                     4
# Item_Fat_Content                0
# Item_Visibility                 0
# Item_Type                       0
# Item_MRP                        0
# Outlet_Identifier               0
# Outlet_Establishment_Year       0
# Outlet_Size                  2410
# Outlet_Location_Type            0
# Outlet_Type                     0
# Item_Outlet_Sales               0
# dtype: int64

# %%
dfTrain[dfTrain['Outlet_Identifier'] == 'OUT045']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 8              FDH17        16.20          Regular             0.02
# 33             FDO23        17.85          Low Fat             0.00
# 46             NCP05        19.60          Low Fat             0.00
# 47             FDV49        10.00          Low Fat             0.03
# 56             NCX54         9.20          Low Fat             0.05
# ...              ...          ...              ...              ...
# 8483           DRI11         8.26          Low Fat             0.03
# 8502           NCH43         8.42          Low Fat             0.07
# 8508           FDW31        11.35          Regular             0.04
# 8514           FDA01        15.00          Regular             0.05
# 8519           FDS36         8.38          Regular             0.05
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 8              Frozen Foods     96.97            OUT045
# ...

# %%
dfTrain['Item_Weight'] = dfTrain.groupby('Item_Identifier')['Item_Weight'].transform(lambda val: val.mean())

# %%
dfTrain[dfTrain['Item_Weight'].isnull()]
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927            FDN52          NaN          Regular             0.13
# 1922           FDK57          NaN          Low Fat             0.08
# 4187           FDE52          NaN          Regular             0.03
# 5022           FDQ60          NaN          Regular             0.19
#
#          Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927   Frozen Foods     86.92            OUT027                       1985
# 1922   Snack Foods    120.04            OUT027                       1985
# 4187         Dairy     88.95            OUT027                       1985
# 5022  Baking Goods    121.21            OUT019                       1985
#
#      Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927       Medium               Tier 3  Supermarket Type3            1569.96
# 1922      Medium               Tier 3  Supermarket Type3            4434.23
# ...

# %%
dfTrain[dfTrain['Item_Identifier'] == 'FDN52']
# Out:
#     Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 927           FDN52          NaN          Regular             0.13
#
#         Item_Type  Item_MRP Outlet_Identifier  Outlet_Establishment_Year  \
# 927  Frozen Foods     86.92            OUT027                       1985
#
#     Outlet_Size Outlet_Location_Type        Outlet_Type  Item_Outlet_Sales
# 927      Medium               Tier 3  Supermarket Type3            1569.96

# %%
dfTrain['Item_Weight'] = dfTrain['Item_Weight'].fillna(0)

# %%
dfTrain.head(5)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
dfTrain['Item_Fat_Content'].unique()
dfTrain['Item_Type'].unique()
# Out:
# array(['Dairy', 'Soft Drinks', 'Meat', 'Fruits and Vegetables',
#        'Household', 'Baking Goods', 'Snack Foods', 'Frozen Foods',
#        'Breakfast', 'Health and Hygiene', 'Hard Drinks', 'Canned',
#        'Breads', 'Starchy Foods', 'Others', 'Seafood'], dtype=object)

# %%
dfTrain[dfTrain['Item_Fat_Content'] == 'LF']
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 45             FDM39         6.42               LF             0.09
# 65             FDC46        17.70               LF             0.20
# 121            DRJ13        12.65               LF             0.06
# 175            FDR47        17.85               LF             0.00
# 207            DRF36        16.10               LF             0.02
# ...              ...          ...              ...              ...
# 8367           FDA32        14.00               LF             0.05
# 8379           FDV39        11.30               LF             0.01
# 8391           FDV15        10.30               LF             0.15
# 8443           FDX15        17.20               LF             0.16
# 8467           FDV31         9.80               LF             0.00
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 45                    Dairy    178.10            OUT010
# ...

# %%
dfTrain.loc[dfTrain['Item_Fat_Content'] == 'low fat', 'Item_Fat_Content'] = 'Low Fat'
dfTrain.loc[dfTrain['Item_Fat_Content'] == 'reg', 'Item_Fat_Content'] = 'Regular'
dfTrain.loc[dfTrain['Item_Fat_Content'] == 'LF', 'Item_Fat_Content'] = 'Low Fat'

# %%
dfTrain.head(10)
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
# 5           FDP36        10.39          Regular             0.00
# 6           FDO10        13.65          Regular             0.01
# 7           FDP10        19.00          Low Fat             0.13
# 8           FDH17        16.20          Regular             0.02
# 9           FDU28        19.20          Regular             0.09
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# ...

# %%
#room_type encoding
fat_dummies = pd.get_dummies(dfTrain['Item_Fat_Content'])
print(fat_dummies)
dfTrain = pd. concat([dfTrain, fat_dummies], axis = 'columns')
dfTrain.head()
# Out:
#       Low Fat  Regular
# 0           1        0
# 1           0        1
# 2           1        0
# 3           0        1
# 4           1        0
# ...       ...      ...
# 8518        1        0
# 8519        0        1
# 8520        1        0
# 8521        0        1
# 8522        1        0
#
# [8523 rows x 2 columns]
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# ...

# %%
dfTrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Item_type

# %%
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the categorical column
dfTrain['item_type_encoded'] = label_encoder.fit_transform(dfTrain['Item_Type'])
print(dfTrain)
# Out:
#      Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0              FDA15         9.30          Low Fat             0.02
# 1              DRC01         5.92          Regular             0.02
# 2              FDN15        17.50          Low Fat             0.02
# 3              FDX07        19.20          Regular             0.00
# 4              NCD19         8.93          Low Fat             0.00
# ...              ...          ...              ...              ...
# 8518           FDF22         6.87          Low Fat             0.06
# 8519           FDS36         8.38          Regular             0.05
# 8520           NCJ29        10.60          Low Fat             0.04
# 8521           FDN46         7.21          Regular             0.15
# 8522           DRG01        14.80          Low Fat             0.04
#
#                   Item_Type  Item_MRP Outlet_Identifier  \
# 0                     Dairy    249.81            OUT049
# ...

# %%
dfTrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
dfTrain['Item_Identifier'].nunique()
dfTrain['Outlet_Identifier'].nunique()

# dfTrain.shape
# Out:
# 10

# %%
# Outlet_Identifier
from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the categorical column
dfTrain['outlet_identifier_encoded'] = label_encoder.fit_transform(dfTrain['Outlet_Identifier'])

# %%
dfTrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Outlet_Location_Type

dfTrain['Outlet_Location_Type'].nunique()

from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the categorical column
dfTrain['outlet_location_type_encoded'] = label_encoder.fit_transform(dfTrain['Outlet_Location_Type'])

# %%
dfTrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
# Outlet_Type

dfTrain['Outlet_Type'].nunique()

from sklearn.preprocessing import LabelEncoder
# Initialize LabelEncoder
label_encoder = LabelEncoder()
# Fit and transform the categorical column
dfTrain['outlet_type_encoded'] = label_encoder.fit_transform(dfTrain['Outlet_Type'])
# Out:
# 4

# %%
dfTrain.head()
# Out:
#   Item_Identifier  Item_Weight Item_Fat_Content  Item_Visibility  \
# 0           FDA15         9.30          Low Fat             0.02
# 1           DRC01         5.92          Regular             0.02
# 2           FDN15        17.50          Low Fat             0.02
# 3           FDX07        19.20          Regular             0.00
# 4           NCD19         8.93          Low Fat             0.00
#
#                Item_Type  Item_MRP Outlet_Identifier  \
# 0                  Dairy    249.81            OUT049
# 1            Soft Drinks     48.27            OUT018
# 2                   Meat    141.62            OUT049
# 3  Fruits and Vegetables    182.09            OUT010
# 4              Household     53.86            OUT013
#
#    Outlet_Establishment_Year Outlet_Size Outlet_Location_Type  \
# 0                       1999      Medium               Tier 1
# 1                       2009      Medium               Tier 3
# ...

# %%
dfTrain.drop(['Item_Identifier', 'Item_Fat_Content', 'Item_Type', 'Outlet_Identifier', 'Outlet_Establishment_Year', 'Outlet_Size', 'Outlet_Location_Type', 'Outlet_Type'], axis = 1, inplace = True)
dfTrain.head()
# Out:
#    Item_Weight  Item_Visibility  Item_MRP  Item_Outlet_Sales  Low Fat  \
# 0         9.30             0.02    249.81            3735.14        1
# 1         5.92             0.02     48.27             443.42        0
# 2        17.50             0.02    141.62            2097.27        1
# 3        19.20             0.00    182.09             732.38        0
# 4         8.93             0.00     53.86             994.71        1
#
#    Regular  item_type_encoded  outlet_identifier_encoded  \
# 0        0                  4                          9
# 1        1                 14                          3
# 2        0                 10                          9
# 3        1                  6                          0
# 4        0                  9                          1
#
#    outlet_location_type_encoded  outlet_type_encoded
# 0                             0                    1
# 1                             2                    2
# ...

# %%
dfTrain.count()
# Out:
# Item_Weight                     8523
# Item_Visibility                 8523
# Item_MRP                        8523
# Item_Outlet_Sales               8523
# Low Fat                         8523
# Regular                         8523
# item_type_encoded               8523
# outlet_identifier_encoded       8523
# outlet_location_type_encoded    8523
# outlet_type_encoded             8523
# dtype: int64

# %%
# Model Building

X = dfTrain.drop(['Item_Outlet_Sales'], axis=1)  #independent
y = dfTrain['Item_Outlet_Sales']  #dependent/target

# %%
from sklearn.model_selection import train_test_split
X_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state=0)

# %%
#Linear Regression
from sklearn.linear_model import LinearRegression
linear = LinearRegression()  #object
linear.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = linear.predict(x_test)

# %%
y_pred
# Out:
# array([2373.18335573, 2567.51956523, 1762.23617537, ..., 3620.17249688,
#        -321.35717743, 5429.28337465])

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y_test, y_pred)
# Out:
# 917.4869699116928

# %%
# XgBoost

# %%
from xgboost import XGBRegressor

xgb = XGBRegressor()

# %%
xgb.fit(X_train, y_train)

y_pred_2 = xgb.predict(x_test)

# %%
mean_absolute_error(y_test, y_pred_2)
# Out:
# 864.0719299175493

# %%
dfTrain.isnull().sum()
# Out:
# Item_Weight                     0
# Item_Visibility                 0
# Item_MRP                        0
# Item_Outlet_Sales               0
# Low Fat                         0
# Regular                         0
# item_type_encoded               0
# outlet_identifier_encoded       0
# outlet_location_type_encoded    0
# outlet_type_encoded             0
# dtype: int64
